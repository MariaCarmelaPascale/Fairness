# %% [markdown]
# <a href="https://colab.research.google.com/github/MariaCarmelaPascale/Fairness/blob/master/Fairness/Esperimenti/MelaTerzoEsperimento.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from oauth2client.client import GoogleCredentials
from google.colab import auth
import pandas as pd
import csv
import matplotlib.pyplot as plt
import numpy as np

auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive = GoogleDrive(gauth)

sort = 'Relevance'

relevance = '1nwGbyk8q2S-0BkLcyFVqdK6emTooxHJv'  # FILE ID, got on google drive with condivision link
download = drive.CreateFile({'id': relevance})
download.GetContentFile('AllRestaurant_' + '%s' % sort + '_Analysis.csv')

dfr = pd.read_csv('AllRestaurant_' + '%s' % sort + '_Analysis.csv')

sort = 'Date'

date = '1Pb2It9WPid9Irjp6bRVgCF7B3Y5ARBjT'  # FILE ID, got on google drive with condivision link
download = drive.CreateFile({'id': date})
download.GetContentFile('AllRestaurant_' + '%s' % sort + '_Analysis.csv')

dfd = pd.read_csv('AllRestaurant_' + '%s' % sort + '_Analysis.csv')

# %%
#elimimo i non riconosciuti
dfr = dfr[(dfr['age'] != 'Not recognized')]
#converto l'eta in numero
dfr['age'] = pd.to_numeric(dfr['age'], errors='coerce').fillna(0).astype(np.int64)
dfr = dfr[(dfr['age']!= 0 )]

#elimimo i non riconosciuti
dfd = dfd[((dfd['age'] != 'Not recognized'))]
#converto l'età in nuemro
dfd['age'] = pd.to_numeric(dfd['age'], errors='coerce').fillna(0).astype(np.int64)
dfr = dfr[(dfr['age']!= 0 )]

# %%
primo_undertrenta = len(dfr[(dfr['age']<=30) & (dfr['number']==1)]) 
print(dfr[(dfr['age']<=30) & (dfr['number']==1)])
primo_trentaquaranta = len(dfr[(dfr['age']>30) & (dfr['age']<40) & (dfr['number']==1)])
primo_quarantacinquanta = len(dfr[(dfr['age']>=40) & (dfr['age']<55) & (dfr['number']==1)]) 
primo_overcinquanta = len(dfr[(dfr['age']>=55) & (dfr['number']==1)]) 

print(primo_undertrenta)
print(primo_trentaquaranta)
print(primo_quarantacinquanta)
print(primo_overcinquanta)

secondo_undertrenta = len(dfr[(dfr['age']<=30) & (dfr['number']==2)]) 
secondo_trentaquaranta = len(dfr[(dfr['age']>30) & (dfr['age']<40) & (dfr['number']==2)]) 
secondo_quarantacinquanta = len(dfr[(dfr['age']>=40) & (dfr['age']<55) & (dfr['number']==2)]) 
secondo_overcinquanta = len(dfr[(dfr['age']>=55) & (dfr['number']==2)]) 
print('=======SECONDO=====')
print(secondo_undertrenta)
print(secondo_trentaquaranta)
print(secondo_quarantacinquanta)
print(secondo_overcinquanta)

terzo_undertrenta = len(dfr[(dfr['age']<=30) & (dfr['number']==3)]) 
terzo_trentaquaranta = len(dfr[(dfr['age']>30) & (dfr['age']<40) & (dfr['number']==3)]) 
terzo_quarantacinquanta = len(dfr[(dfr['age']>=40) & (dfr['age']<55) & (dfr['number']==3)]) 
terzo_overcinquanta = len(dfr[(dfr['age']>=55) & (dfr['number']==3)]) 
print('=======TERZO=====')
print(terzo_undertrenta)
print(terzo_trentaquaranta)
print(terzo_quarantacinquanta)
print(terzo_overcinquanta)


quarto_undertrenta = len(dfr[(dfr['age']<=30) & (dfr['number']==4)]) 
quarto_trentaquaranta = len(dfr[(dfr['age']>30) & (dfr['age']<40) & (dfr['number']==4)]) 
quarto_quarantacinquanta = len(dfr[(dfr['age']>=40) & (dfr['age']<55) & (dfr['number']==4)]) 
quarto_overcinquanta = len(dfr[(dfr['age']>=55) & (dfr['number']==4)]) 

print('=======QUARTO=====')
print(quarto_undertrenta)
print(quarto_trentaquaranta)
print(quarto_quarantacinquanta)
print(quarto_overcinquanta)

quinto_undertrenta = len(dfr[(dfr['age']<=30) & (dfr['number']==5)]) 
quinto_trentaquaranta = len(dfr[(dfr['age']>30) & (dfr['age']<40) & (dfr['number']==5)]) 
quinto_quarantacinquanta = len(dfr[(dfr['age']>=40) & (dfr['age']<55) & (dfr['number']==5)]) 
quinto_overcinquanta = len(dfr[(dfr['age']>=55) & (dfr['number']==5)]) 

print('=======QUINTO=====')
print(quinto_undertrenta)
print(quinto_trentaquaranta)
print(quinto_quarantacinquanta)
print(quinto_overcinquanta)

sesto_undertrenta = len(dfr[(dfr['age']<=30) & (dfr['number']==6)]) 
sesto_trentaquaranta = len(dfr[(dfr['age']>30) & (dfr['age']<40) & (dfr['number']==6)]) 
sesto_quarantacinquanta = len(dfr[(dfr['age']>=40) & (dfr['age']<55) & (dfr['number']==6)]) 
sesto_overcinquanta = len(dfr[(dfr['age']>=55) & (dfr['number']==6)]) 

settimo_undertrenta = len(dfr[(dfr['age']<=30) & (dfr['number']==7)]) 
settimo_trentaquaranta = len(dfr[(dfr['age']>30) & (dfr['age']<40) & (dfr['number']==7)]) 
settimo_quarantacinquanta = len(dfr[(dfr['age']>=40) & (dfr['age']<55) & (dfr['number']==7)]) 
settimo_overcinquanta = len(dfr[(dfr['age']>=55) & (dfr['number']==7)]) 

ottavo_undertrenta = len(dfr[(dfr['age']<=30) & (dfr['number']==8)]) 
ottavo_trentaquaranta = len(dfr[(dfr['age']>30) & (dfr['age']<40) & (dfr['number']==8)]) 
ottavo_quarantacinquanta = len(dfr[(dfr['age']>=40) & (dfr['age']<55) & (dfr['number']==8)]) 
ottavo_overcinquanta = len(dfr[(dfr['age']>=55) & (dfr['number']==8)]) 

nono_undertrenta = len(dfr[(dfr['age']<=30) & (dfr['number']==9)]) 
nono_trentaquaranta = len(dfr[(dfr['age']>30) & (dfr['age']<40) & (dfr['number']==9)]) 
nono_quarantacinquanta = len(dfr[(dfr['age']>=40) & (dfr['age']<55) & (dfr['number']==9)]) 
nono_overcinquanta = len(dfr[(dfr['age']>=55) & (dfr['number']==9)]) 

decimo_undertrenta = len(dfr[(dfr['age']<=30) & (dfr['number']==10)]) 
decimo_trentaquaranta = len(dfr[(dfr['age']>30) & (dfr['age']<40) & (dfr['number']==10)]) 
decimo_quarantacinquanta = len(dfr[(dfr['age']>=40) & (dfr['age']<55) & (dfr['number']==10)]) 
decimo_overcinquanta = len(dfr[(dfr['age']>=55) & (dfr['number']==10)]) 

undicesimo_undertrenta = len(dfr[(dfr['age']<=30) & (dfr['number']==11)]) 
undicesimo_trentaquaranta = len(dfr[(dfr['age']>30) & (dfr['age']<40) & (dfr['number']==11)]) 
undicesimo_quarantacinquanta = len(dfr[(dfr['age']>=40) & (dfr['age']<55) & (dfr['number']==11)]) 
undicesimo_overcinquanta = len(dfr[(dfr['age']>=55) & (dfr['number']==11)]) 

dodicesimo_undertrenta = len(dfr[(dfr['age']<=30) & (dfr['number']==12)]) 
dodicesimo_trentaquaranta = len(dfr[(dfr['age']>30) & (dfr['age']<40) & (dfr['number']==12)]) 
dodicesimo_quarantacinquanta = len(dfr[(dfr['age']>=40) & (dfr['age']<55) & (dfr['number']==12)]) 
dodicesimo_overcinquanta = len(dfr[(dfr['age']>=55) & (dfr['number']==12)]) 

tredi_undertrenta = len(dfr[(dfr['age']<=30) & (dfr['number']==13)]) 
tredi_trentaquaranta = len(dfr[(dfr['age']>30) & (dfr['age']<40) & (dfr['number']==13)]) 
tredi_quarantacinquanta = len(dfr[(dfr['age']>=40) & (dfr['age']<55) & (dfr['number']==13)]) 
tredi_overcinquanta = len(dfr[(dfr['age']>=55) & (dfr['number']==13)]) 

quattordi_undertrenta = len(dfr[(dfr['age']<=30) & (dfr['number']==14)]) 
quattordi_trentaquaranta = len(dfr[(dfr['age']>30) & (dfr['age']<40) & (dfr['number']==14)]) 
quattordi_quarantacinquanta = len(dfr[(dfr['age']>=40) & (dfr['age']<55) & (dfr['number']==14)]) 
quattordi_overcinquanta = len(dfr[(dfr['age']>=55) & (dfr['number']==14)]) 

quindi_undertrenta = len(dfr[(dfr['age']<=30) & (dfr['number']==15)]) 
quindi_trentaquaranta = len(dfr[(dfr['age']>30) & (dfr['age']<40) & (dfr['number']==15)]) 
quindi_quarantacinquanta = len(dfr[(dfr['age']>=40) & (dfr['age']<55) & (dfr['number']==15)]) 
quindi_overcinquanta = len(dfr[(dfr['age']>=55) & (dfr['number']==15)]) 

sedi_undertrenta = len(dfr[(dfr['age']<=30) & (dfr['number']==16)]) 
sedi_trentaquaranta = len(dfr[(dfr['age']>30) & (dfr['age']<40) & (dfr['number']==16)]) 
sedi_quarantacinquanta = len(dfr[(dfr['age']>=40) & (dfr['age']<55) & (dfr['number']==16)]) 
sedi_overcinquanta = len(dfr[(dfr['age']>=55) & (dfr['number']==16)]) 

dicia_undertrenta = len(dfr[(dfr['age']<=30) & (dfr['number']==17)]) 
dicia_trentaquaranta = len(dfr[(dfr['age']>30) & (dfr['age']<40) & (dfr['number']==17)]) 
dicia_quarantacinquanta = len(dfr[(dfr['age']>=40) & (dfr['age']<55) & (dfr['number']==17)]) 
dicia_overcinquanta = len(dfr[(dfr['age']>=55) & (dfr['number']==17)]) 

dicio_undertrenta = len(dfr[(dfr['age']<=30) & (dfr['number']==18)]) 
dicio_trentaquaranta = len(dfr[(dfr['age']>30) & (dfr['age']<40) & (dfr['number']==18)]) 
dicio_quarantacinquanta = len(dfr[(dfr['age']>=40) & (dfr['age']<55) & (dfr['number']==18)]) 
dicio_overcinquanta = len(dfr[(dfr['age']>=55) & (dfr['number']==18)]) 

dician_undertrenta = len(dfr[(dfr['age']<=30) & (dfr['number']==19)]) 
dician_trentaquaranta = len(dfr[(dfr['age']>30) & (dfr['age']<40) & (dfr['number']==19)]) 
dician_quarantacinquanta = len(dfr[(dfr['age']>=40) & (dfr['age']<55) & (dfr['number']==19)]) 
dician_overcinquanta = len(dfr[(dfr['age']>=55) & (dfr['number']==19)]) 

venti_undertrenta = len(dfr[(dfr['age']<=30) & (dfr['number']==20)]) 
venti_trentaquaranta = len(dfr[(dfr['age']>30) & (dfr['age']<40) & (dfr['number']==20)]) 
venti_quarantacinquanta = len(dfr[(dfr['age']>=40) & (dfr['age']<55) & (dfr['number']==20)]) 
venti_overcinquanta = len(dfr[(dfr['age']>=55) & (dfr['number']==20)])
# Out:
#     restaurant  ... review_sentiment
# 0  TupeloHoney  ...         positive
#
# [1 rows x 10 columns]
# 1
# 1
# 2
# 0
# =======SECONDO=====
# 2
# 5
# 0
# 0
# =======TERZO=====
# 1
# 3
# 0
# 2
# =======QUARTO=====
# 1
# 4
# 1
# 1
# =======QUINTO=====
# 2
# 4
# 1
# 0

# %%
#================COSTRUISCO GRAFICO RELEVANCE=====================
plt.subplot()
#fig, ax = plt.subplots()

#=======<30=======
plt.scatter(1, 1, s=primo_undertrenta*20, color= 'blue' , alpha=0.5, label='undertrenta')
plt.scatter(1, 2, s = secondo_undertrenta*20, color= 'blue',  alpha=0.5)
plt.scatter(1, 3, s=terzo_undertrenta*20,color= 'blue', alpha=0.5)
plt.scatter(1, 4, s=quarto_undertrenta*20, color= 'blue' , alpha=0.5)
plt.scatter(1, 5, s = quinto_undertrenta*20, color= 'blue',  alpha=0.5)
plt.scatter(1, 6, s=sesto_undertrenta*20,color= 'blue', alpha=0.5)
plt.scatter(1, 7, s=settimo_undertrenta*20, color= 'blue' , alpha=0.5)
plt.scatter(1, 8, s = ottavo_undertrenta*20, color= 'blue',  alpha=0.5)
plt.scatter(1, 9, s=nono_undertrenta*20,color= 'blue', alpha=0.5)
plt.scatter(1, 10, s=decimo_undertrenta*20, color= 'blue' , alpha=0.5)
plt.scatter(1, 11, s=undicesimo_undertrenta*20, color= 'blue' , alpha=0.5)
plt.scatter(1, 12, s = dodicesimo_undertrenta*20, color= 'blue',  alpha=0.5)
plt.scatter(1, 13, s=tredi_undertrenta*20,color= 'blue', alpha=0.5)
plt.scatter(1, 14, s=quattordi_undertrenta*20, color= 'blue' , alpha=0.5)
plt.scatter(1, 15, s = quindi_undertrenta*20, color= 'blue',  alpha=0.5)
plt.scatter(1, 16, s=sedi_undertrenta*20,color= 'blue', alpha=0.5)
plt.scatter(1, 17, s=dicia_undertrenta*20, color= 'blue' , alpha=0.5)
plt.scatter(1, 18, s = dicio_undertrenta*20, color= 'blue',  alpha=0.5)
plt.scatter(1, 19, s=dician_undertrenta*20,color= 'blue', alpha=0.5)
plt.scatter(1, 20, s=venti_undertrenta*20, color= 'blue' , alpha=0.5)


#====30-40=====
plt.scatter(2, 1, s=primo_trentaquaranta*20, color= 'green' , alpha=0.5, label='trentaquaranta')
plt.scatter(2, 2, s = secondo_trentaquaranta*20, color= 'green',  alpha=0.5)
plt.scatter(2, 3, s=terzo_trentaquaranta*20,color= 'green', alpha=0.5)
plt.scatter(2, 4, s=quarto_trentaquaranta*20, color= 'green' , alpha=0.5)
plt.scatter(2, 5, s = quinto_trentaquaranta*20, color= 'green',  alpha=0.5)
plt.scatter(2, 6, s=sesto_trentaquaranta*20,color= 'green', alpha=0.5)
plt.scatter(2, 7, s=settimo_trentaquaranta*20, color= 'green' , alpha=0.5)
plt.scatter(2, 8, s = ottavo_trentaquaranta*20, color= 'green',  alpha=0.5)
plt.scatter(2, 9, s=nono_trentaquaranta*20,color= 'green', alpha=0.5)
plt.scatter(2, 10, s=decimo_trentaquaranta*20, color= 'green' , alpha=0.5)
plt.scatter(2, 11, s=undicesimo_trentaquaranta*20, color= 'green' , alpha=0.5)
plt.scatter(2, 12, s = dodicesimo_trentaquaranta*20, color= 'green',  alpha=0.5)
plt.scatter(2, 13, s=tredi_trentaquaranta*20,color= 'green', alpha=0.5)
plt.scatter(2, 14, s=quattordi_trentaquaranta*20, color= 'green' , alpha=0.5)
plt.scatter(2, 15, s = quindi_trentaquaranta*20, color= 'green',  alpha=0.5)
plt.scatter(2, 16, s=sedi_trentaquaranta*20,color= 'green', alpha=0.5)
plt.scatter(2, 17, s=dicia_trentaquaranta*20, color= 'green' , alpha=0.5)
plt.scatter(2, 18, s = dicio_trentaquaranta*20, color= 'green',  alpha=0.5)
plt.scatter(2, 19, s=dician_trentaquaranta*20,color= 'green', alpha=0.5)
plt.scatter(2, 20, s=venti_trentaquaranta*20, color= 'green' , alpha=0.5)


#======40-55=========
plt.scatter(3, 1, s=primo_quarantacinquanta*20, color= 'red' , alpha=0.5)
plt.scatter(3, 2, s = secondo_quarantacinquanta*20, color= 'red',  alpha=0.5)
plt.scatter(3, 3, s=terzo_quarantacinquanta*20,color= 'red', alpha=0.5)
plt.scatter(3, 4, s=quarto_quarantacinquanta*20, color= 'red' , alpha=0.5)
plt.scatter(3, 5, s = quinto_quarantacinquanta*20, color= 'red',  alpha=0.5)
plt.scatter(3, 6, s=sesto_quarantacinquanta*20,color= 'red', alpha=0.5)
plt.scatter(3, 7, s=settimo_quarantacinquanta*20, color= 'red' , alpha=0.5)
plt.scatter(3, 8, s = ottavo_quarantacinquanta*20, color= 'red',  alpha=0.5)
plt.scatter(3, 9, s=nono_quarantacinquanta*20,color= 'red', alpha=0.5)
plt.scatter(3, 10, s=decimo_quarantacinquanta*20, color= 'red' , alpha=0.5)
plt.scatter(3, 11, s=undicesimo_quarantacinquanta*20, color= 'red' , alpha=0.5)
plt.scatter(3, 12, s = dodicesimo_quarantacinquanta*20, color= 'red',  alpha=0.5)
plt.scatter(3, 13, s=tredi_quarantacinquanta*20,color= 'red', alpha=0.5)
plt.scatter(3, 14, s=quattordi_quarantacinquanta*20, color= 'red' , alpha=0.5)
plt.scatter(3, 15, s = quindi_quarantacinquanta*20, color= 'red',  alpha=0.5)
plt.scatter(3, 16, s=sedi_quarantacinquanta*20,color= 'red', alpha=0.5)
plt.scatter(3, 17, s=dicia_quarantacinquanta*20, color= 'red' , alpha=0.5)
plt.scatter(3, 18, s = dicio_quarantacinquanta*20, color= 'red',  alpha=0.5)
plt.scatter(3, 19, s=dician_quarantacinquanta*20,color= 'red', alpha=0.5)
plt.scatter(3, 20, s=venti_quarantacinquanta*20, color= 'red' , alpha=0.5)



#========>55=======
plt.scatter(4, 1, s=primo_overcinquanta*20, color= 'orange' , alpha=0.5)
plt.scatter(4, 2, s = secondo_overcinquanta*20, color= 'orange',  alpha=0.5)
plt.scatter(4, 3, s=terzo_overcinquanta*20,color= 'orange', alpha=0.5)
plt.scatter(4, 4, s=quarto_overcinquanta*20, color= 'orange' , alpha=0.5)
plt.scatter(4, 5, s = quinto_overcinquanta*20, color= 'orange',  alpha=0.5)
plt.scatter(4, 6, s=sesto_overcinquanta*20,color= 'orange', alpha=0.5)
plt.scatter(4, 7, s=settimo_overcinquanta*20, color= 'orange' , alpha=0.5)
plt.scatter(4, 8, s = ottavo_overcinquanta*20, color= 'orange',  alpha=0.5)
plt.scatter(4, 9, s=nono_overcinquanta*20,color= 'orange', alpha=0.5)
plt.scatter(4, 10, s=decimo_overcinquanta*20, color= 'orange' , alpha=0.5)
plt.scatter(4, 11, s=undicesimo_overcinquanta*20, color= 'orange' , alpha=0.5)
plt.scatter(4, 12, s = dodicesimo_overcinquanta*20, color= 'orange',  alpha=0.5)
plt.scatter(4, 13, s=tredi_overcinquanta*20,color= 'orange', alpha=0.5)
plt.scatter(4, 14, s=quattordi_overcinquanta*20, color= 'orange' , alpha=0.5)
plt.scatter(4, 15, s = quindi_overcinquanta*20, color= 'orange',  alpha=0.5)
plt.scatter(4, 16, s=sedi_overcinquanta*20,color= 'orange', alpha=0.5)
plt.scatter(4, 17, s=dicia_overcinquanta*20, color= 'orange' , alpha=0.5)
plt.scatter(4, 18, s = dicio_overcinquanta*20, color= 'orange',  alpha=0.5)
plt.scatter(4, 19, s=dician_overcinquanta*20,color= 'orange', alpha=0.5)
plt.scatter(4, 20, s=venti_overcinquanta*20, color= 'orange' , alpha=0.5)





#=======RIFINITURE========
plt.hlines(y=11, xmin=1, xmax=5)

plt.title('Distribuzione demografica nelle prime 20 posizioni secondo ordinamento di Yelp ')
plt.ylabel('Posizione in classifica', labelpad = 16)
plt.xlabel('Fascia di età' , labelpad = 16)
#setta ogni quante y ti fa vedere
plt.yticks(np.arange(0, 20, 5.0))
plt.xticks(np.arange(1, 6, 1.0))
plt.xticks([1,2,3,4],['under 30','30-40','40-55','over 55'],rotation=90)
plt.show()

# %%
primo_undertrenta = len(dfd[(dfd['age']<=30) & (dfd['number']==1)]) 
print(dfd[(dfd['age']<=30) & (dfd['number']==1)])
primo_trentaquaranta = len(dfd[(dfd['age']>30) & (dfd['age']<40) & (dfd['number']==1)])
primo_quarantacinquanta = len(dfd[(dfd['age']>=40) & (dfd['age']<55) & (dfd['number']==1)]) 
primo_overcinquanta = len(dfd[(dfd['age']>=55) & (dfd['number']==1)]) 

print(primo_undertrenta)
print(primo_trentaquaranta)
print(primo_quarantacinquanta)
print(primo_overcinquanta)

secondo_undertrenta = len(dfd[(dfd['age']<=30) & (dfd['number']==2)]) 
secondo_trentaquaranta = len(dfd[(dfd['age']>30) & (dfd['age']<40) & (dfd['number']==2)]) 
secondo_quarantacinquanta = len(dfd[(dfd['age']>=40) & (dfd['age']<55) & (dfd['number']==2)]) 
secondo_overcinquanta = len(dfd[(dfd['age']>=55) & (dfd['number']==2)]) 
print('=======SECONDO=====')
print(secondo_undertrenta)
print(secondo_trentaquaranta)
print(secondo_quarantacinquanta)
print(secondo_overcinquanta)

terzo_undertrenta = len(dfd[(dfd['age']<=30) & (dfd['number']==3)]) 
terzo_trentaquaranta = len(dfd[(dfd['age']>30) & (dfd['age']<40) & (dfd['number']==3)]) 
terzo_quarantacinquanta = len(dfd[(dfd['age']>=40) & (dfd['age']<55) & (dfd['number']==3)]) 
terzo_overcinquanta = len(dfd[(dfd['age']>=55) & (dfd['number']==3)]) 
print('=======TERZO=====')
print(terzo_undertrenta)
print(terzo_trentaquaranta)
print(terzo_quarantacinquanta)
print(terzo_overcinquanta)

quarto_undertrenta = len(dfd[(dfd['age']<=30) & (dfd['number']==4)]) 
quarto_trentaquaranta = len(dfd[(dfd['age']>30) & (dfd['age']<40) & (dfd['number']==4)]) 
quarto_quarantacinquanta = len(dfd[(dfd['age']>=40) & (dfd['age']<55) & (dfd['number']==4)]) 
quarto_overcinquanta = len(dfd[(dfd['age']>=55) & (dfd['number']==4)]) 

print('=======QUARTO=====')
print(quarto_undertrenta)
print(quarto_trentaquaranta)
print(quarto_quarantacinquanta)
print(quarto_overcinquanta)

quinto_undertrenta = len(dfd[(dfd['age']<=30) & (dfd['number']==5)]) 
quinto_trentaquaranta = len(dfd[(dfd['age']>30) & (dfd['age']<40) & (dfd['number']==5)]) 
quinto_quarantacinquanta = len(dfd[(dfd['age']>=40) & (dfd['age']<55) & (dfd['number']==5)]) 
quinto_overcinquanta = len(dfd[(dfd['age']>=55) & (dfd['number']==5)]) 

print('=======QUINTO=====')
print(quinto_undertrenta)
print(quinto_trentaquaranta)
print(quinto_quarantacinquanta)
print(quinto_overcinquanta)

sesto_undertrenta = len(dfd[(dfd['age']<=30) & (dfd['number']==6)]) 
sesto_trentaquaranta = len(dfd[(dfd['age']>30) & (dfd['age']<40) & (dfd['number']==6)]) 
sesto_quarantacinquanta = len(dfd[(dfd['age']>=40) & (dfd['age']<55) & (dfd['number']==6)]) 
sesto_overcinquanta = len(dfd[(dfd['age']>=55) & (dfd['number']==6)]) 

settimo_undertrenta = len(dfd[(dfd['age']<=30) & (dfd['number']==7)]) 
settimo_trentaquaranta = len(dfd[(dfd['age']>30) & (dfd['age']<40) & (dfd['number']==7)]) 
settimo_quarantacinquanta = len(dfd[(dfd['age']>=40) & (dfd['age']<55) & (dfd['number']==7)]) 
settimo_overcinquanta = len(dfd[(dfd['age']>=55) & (dfd['number']==7)]) 

ottavo_undertrenta = len(dfd[(dfd['age']<=30) & (dfd['number']==8)]) 
ottavo_trentaquaranta = len(dfd[(dfd['age']>30) & (dfd['age']<40) & (dfd['number']==8)]) 
ottavo_quarantacinquanta = len(dfd[(dfd['age']>=40) & (dfd['age']<55) & (dfd['number']==8)]) 
ottavo_overcinquanta = len(dfd[(dfd['age']>=55) & (dfd['number']==8)]) 

nono_undertrenta = len(dfd[(dfd['age']<=30) & (dfd['number']==9)]) 
nono_trentaquaranta = len(dfd[(dfd['age']>30) & (dfd['age']<40) & (dfd['number']==9)]) 
nono_quarantacinquanta = len(dfd[(dfd['age']>=40) & (dfd['age']<55) & (dfd['number']==9)]) 
nono_overcinquanta = len(dfd[(dfd['age']>=55) & (dfd['number']==9)]) 

decimo_undertrenta = len(dfd[(dfd['age']<=30) & (dfd['number']==10)]) 
decimo_trentaquaranta = len(dfd[(dfd['age']>30) & (dfd['age']<40) & (dfd['number']==10)]) 
decimo_quarantacinquanta = len(dfd[(dfd['age']>=40) & (dfd['age']<55) & (dfd['number']==10)]) 
decimo_overcinquanta = len(dfd[(dfd['age']>=55) & (dfd['number']==10)]) 

undicesimo_undertrenta = len(dfd[(dfd['age']<=30) & (dfd['number']==11)]) 
undicesimo_trentaquaranta = len(dfd[(dfd['age']>30) & (dfd['age']<40) & (dfd['number']==11)]) 
undicesimo_quarantacinquanta = len(dfd[(dfd['age']>=40) & (dfd['age']<55) & (dfd['number']==11)]) 
undicesimo_overcinquanta = len(dfd[(dfd['age']>=55) & (dfd['number']==11)]) 

dodicesimo_undertrenta = len(dfd[(dfd['age']<=30) & (dfd['number']==12)]) 
dodicesimo_trentaquaranta = len(dfd[(dfd['age']>30) & (dfd['age']<40) & (dfd['number']==12)]) 
dodicesimo_quarantacinquanta = len(dfd[(dfd['age']>=40) & (dfd['age']<55) & (dfd['number']==12)]) 
dodicesimo_overcinquanta = len(dfd[(dfd['age']>=55) & (dfd['number']==12)]) 

tredi_undertrenta = len(dfd[(dfd['age']<=30) & (dfd['number']==13)]) 
tredi_trentaquaranta = len(dfd[(dfd['age']>30) & (dfd['age']<40) & (dfd['number']==13)]) 
tredi_quarantacinquanta = len(dfd[(dfd['age']>=40) & (dfd['age']<55) & (dfd['number']==13)]) 
tredi_overcinquanta = len(dfd[(dfd['age']>=55) & (dfd['number']==13)]) 

quattordi_undertrenta = len(dfd[(dfd['age']<=30) & (dfd['number']==14)]) 
quattordi_trentaquaranta = len(dfd[(dfd['age']>30) & (dfd['age']<40) & (dfd['number']==14)]) 
quattordi_quarantacinquanta = len(dfd[(dfd['age']>=40) & (dfd['age']<55) & (dfd['number']==14)]) 
quattordi_overcinquanta = len(dfd[(dfd['age']>=55) & (dfd['number']==14)]) 

quindi_undertrenta = len(dfd[(dfd['age']<=30) & (dfd['number']==15)]) 
quindi_trentaquaranta = len(dfd[(dfd['age']>30) & (dfd['age']<40) & (dfd['number']==15)]) 
quindi_quarantacinquanta = len(dfd[(dfd['age']>=40) & (dfd['age']<55) & (dfd['number']==15)]) 
quindi_overcinquanta = len(dfd[(dfd['age']>=55) & (dfd['number']==15)]) 

sedi_undertrenta = len(dfd[(dfd['age']<=30) & (dfd['number']==16)]) 
sedi_trentaquaranta = len(dfd[(dfd['age']>30) & (dfd['age']<40) & (dfd['number']==16)]) 
sedi_quarantacinquanta = len(dfd[(dfd['age']>=40) & (dfd['age']<55) & (dfd['number']==16)]) 
sedi_overcinquanta = len(dfd[(dfd['age']>=55) & (dfd['number']==16)]) 

dicia_undertrenta = len(dfd[(dfd['age']<=30) & (dfd['number']==17)]) 
dicia_trentaquaranta = len(dfd[(dfd['age']>30) & (dfd['age']<40) & (dfd['number']==17)]) 
dicia_quarantacinquanta = len(dfd[(dfd['age']>=40) & (dfd['age']<55) & (dfd['number']==17)]) 
dicia_overcinquanta = len(dfd[(dfd['age']>=55) & (dfd['number']==17)]) 

dicio_undertrenta = len(dfd[(dfd['age']<=30) & (dfd['number']==18)]) 
dicio_trentaquaranta = len(dfd[(dfd['age']>30) & (dfd['age']<40) & (dfd['number']==18)]) 
dicio_quarantacinquanta = len(dfd[(dfd['age']>=40) & (dfd['age']<55) & (dfd['number']==18)]) 
dicio_overcinquanta = len(dfd[(dfd['age']>=55) & (dfd['number']==18)]) 

dician_undertrenta = len(dfd[(dfd['age']<=30) & (dfd['number']==19)]) 
dician_trentaquaranta = len(dfd[(dfd['age']>30) & (dfd['age']<40) & (dfd['number']==19)]) 
dician_quarantacinquanta = len(dfd[(dfd['age']>=40) & (dfd['age']<55) & (dfd['number']==19)]) 
dician_overcinquanta = len(dfd[(dfd['age']>=55) & (dfd['number']==19)]) 

venti_undertrenta = len(dfd[(dfd['age']<=30) & (dfd['number']==20)]) 
venti_trentaquaranta = len(dfd[(dfd['age']>30) & (dfd['age']<40) & (dfd['number']==20)]) 
venti_quarantacinquanta = len(dfd[(dfd['age']>=40) & (dfd['age']<55) & (dfd['number']==20)]) 
venti_overcinquanta = len(dfd[(dfd['age']>=55) & (dfd['number']==20)])

# %%
#================COSTRUISCO GRAFICO RELEVANCE=====================
plt.subplot()
#fig, ax = plt.subplots()

#=======<30=======
plt.scatter(1, 1, s=primo_undertrenta*20, color= 'blue' , alpha=0.5, label='undertrenta')
plt.scatter(1, 2, s = secondo_undertrenta*20, color= 'blue',  alpha=0.5)
plt.scatter(1, 3, s=terzo_undertrenta*20,color= 'blue', alpha=0.5)
plt.scatter(1, 4, s=quarto_undertrenta*20, color= 'blue' , alpha=0.5)
plt.scatter(1, 5, s = quinto_undertrenta*20, color= 'blue',  alpha=0.5)
plt.scatter(1, 6, s=sesto_undertrenta*20,color= 'blue', alpha=0.5)
plt.scatter(1, 7, s=settimo_undertrenta*20, color= 'blue' , alpha=0.5)
plt.scatter(1, 8, s = ottavo_undertrenta*20, color= 'blue',  alpha=0.5)
plt.scatter(1, 9, s=nono_undertrenta*20,color= 'blue', alpha=0.5)
plt.scatter(1, 10, s=decimo_undertrenta*20, color= 'blue' , alpha=0.5)
plt.scatter(1, 11, s=undicesimo_undertrenta*20, color= 'blue' , alpha=0.5)
plt.scatter(1, 12, s = dodicesimo_undertrenta*20, color= 'blue',  alpha=0.5)
plt.scatter(1, 13, s=tredi_undertrenta*20,color= 'blue', alpha=0.5)
plt.scatter(1, 14, s=quattordi_undertrenta*20, color= 'blue' , alpha=0.5)
plt.scatter(1, 15, s = quindi_undertrenta*20, color= 'blue',  alpha=0.5)
plt.scatter(1, 16, s=sedi_undertrenta*20,color= 'blue', alpha=0.5)
plt.scatter(1, 17, s=dicia_undertrenta*20, color= 'blue' , alpha=0.5)
plt.scatter(1, 18, s = dicio_undertrenta*20, color= 'blue',  alpha=0.5)
plt.scatter(1, 19, s=dician_undertrenta*20,color= 'blue', alpha=0.5)
plt.scatter(1, 20, s=venti_undertrenta*20, color= 'blue' , alpha=0.5)


#====30-40=====
plt.scatter(2, 1, s=primo_trentaquaranta*20, color= 'green' , alpha=0.5, label='trentaquaranta')
plt.scatter(2, 2, s = secondo_trentaquaranta*20, color= 'green',  alpha=0.5)
plt.scatter(2, 3, s=terzo_trentaquaranta*20,color= 'green', alpha=0.5)
plt.scatter(2, 4, s=quarto_trentaquaranta*20, color= 'green' , alpha=0.5)
plt.scatter(2, 5, s = quinto_trentaquaranta*20, color= 'green',  alpha=0.5)
plt.scatter(2, 6, s=sesto_trentaquaranta*20,color= 'green', alpha=0.5)
plt.scatter(2, 7, s=settimo_trentaquaranta*20, color= 'green' , alpha=0.5)
plt.scatter(2, 8, s = ottavo_trentaquaranta*20, color= 'green',  alpha=0.5)
plt.scatter(2, 9, s=nono_trentaquaranta*20,color= 'green', alpha=0.5)
plt.scatter(2, 10, s=decimo_trentaquaranta*20, color= 'green' , alpha=0.5)
plt.scatter(2, 11, s=undicesimo_trentaquaranta*20, color= 'green' , alpha=0.5)
plt.scatter(2, 12, s = dodicesimo_trentaquaranta*20, color= 'green',  alpha=0.5)
plt.scatter(2, 13, s=tredi_trentaquaranta*20,color= 'green', alpha=0.5)
plt.scatter(2, 14, s=quattordi_trentaquaranta*20, color= 'green' , alpha=0.5)
plt.scatter(2, 15, s = quindi_trentaquaranta*20, color= 'green',  alpha=0.5)
plt.scatter(2, 16, s=sedi_trentaquaranta*20,color= 'green', alpha=0.5)
plt.scatter(2, 17, s=dicia_trentaquaranta*20, color= 'green' , alpha=0.5)
plt.scatter(2, 18, s = dicio_trentaquaranta*20, color= 'green',  alpha=0.5)
plt.scatter(2, 19, s=dician_trentaquaranta*20,color= 'green', alpha=0.5)
plt.scatter(2, 20, s=venti_trentaquaranta*20, color= 'green' , alpha=0.5)


#======40-55=========
plt.scatter(3, 1, s=primo_quarantacinquanta*20, color= 'red' , alpha=0.5)
plt.scatter(3, 2, s = secondo_quarantacinquanta*20, color= 'red',  alpha=0.5)
plt.scatter(3, 3, s=terzo_quarantacinquanta*20,color= 'red', alpha=0.5)
plt.scatter(3, 4, s=quarto_quarantacinquanta*20, color= 'red' , alpha=0.5)
plt.scatter(3, 5, s = quinto_quarantacinquanta*20, color= 'red',  alpha=0.5)
plt.scatter(3, 6, s=sesto_quarantacinquanta*20,color= 'red', alpha=0.5)
plt.scatter(3, 7, s=settimo_quarantacinquanta*20, color= 'red' , alpha=0.5)
plt.scatter(3, 8, s = ottavo_quarantacinquanta*20, color= 'red',  alpha=0.5)
plt.scatter(3, 9, s=nono_quarantacinquanta*20,color= 'red', alpha=0.5)
plt.scatter(3, 10, s=decimo_quarantacinquanta*20, color= 'red' , alpha=0.5)
plt.scatter(3, 11, s=undicesimo_quarantacinquanta*20, color= 'red' , alpha=0.5)
plt.scatter(3, 12, s = dodicesimo_quarantacinquanta*20, color= 'red',  alpha=0.5)
plt.scatter(3, 13, s=tredi_quarantacinquanta*20,color= 'red', alpha=0.5)
plt.scatter(3, 14, s=quattordi_quarantacinquanta*20, color= 'red' , alpha=0.5)
plt.scatter(3, 15, s = quindi_quarantacinquanta*20, color= 'red',  alpha=0.5)
plt.scatter(3, 16, s=sedi_quarantacinquanta*20,color= 'red', alpha=0.5)
plt.scatter(3, 17, s=dicia_quarantacinquanta*20, color= 'red' , alpha=0.5)
plt.scatter(3, 18, s = dicio_quarantacinquanta*20, color= 'red',  alpha=0.5)
plt.scatter(3, 19, s=dician_quarantacinquanta*20,color= 'red', alpha=0.5)
plt.scatter(3, 20, s=venti_quarantacinquanta*20, color= 'red' , alpha=0.5)



#========>55=======
plt.scatter(4, 1, s=primo_overcinquanta*20, color= 'orange' , alpha=0.5)
plt.scatter(4, 2, s = secondo_overcinquanta*20, color= 'orange',  alpha=0.5)
plt.scatter(4, 3, s=terzo_overcinquanta*20,color= 'orange', alpha=0.5)
plt.scatter(4, 4, s=quarto_overcinquanta*20, color= 'orange' , alpha=0.5)
plt.scatter(4, 5, s = quinto_overcinquanta*20, color= 'orange',  alpha=0.5)
plt.scatter(4, 6, s=sesto_overcinquanta*20,color= 'orange', alpha=0.5)
plt.scatter(4, 7, s=settimo_overcinquanta*20, color= 'orange' , alpha=0.5)
plt.scatter(4, 8, s = ottavo_overcinquanta*20, color= 'orange',  alpha=0.5)
plt.scatter(4, 9, s=nono_overcinquanta*20,color= 'orange', alpha=0.5)
plt.scatter(4, 10, s=decimo_overcinquanta*20, color= 'orange' , alpha=0.5)
plt.scatter(4, 11, s=undicesimo_overcinquanta*20, color= 'orange' , alpha=0.5)
plt.scatter(4, 12, s = dodicesimo_overcinquanta*20, color= 'orange',  alpha=0.5)
plt.scatter(4, 13, s=tredi_overcinquanta*20,color= 'orange', alpha=0.5)
plt.scatter(4, 14, s=quattordi_overcinquanta*20, color= 'orange' , alpha=0.5)
plt.scatter(4, 15, s = quindi_overcinquanta*20, color= 'orange',  alpha=0.5)
plt.scatter(4, 16, s=sedi_overcinquanta*20,color= 'orange', alpha=0.5)
plt.scatter(4, 17, s=dicia_overcinquanta*20, color= 'orange' , alpha=0.5)
plt.scatter(4, 18, s = dicio_overcinquanta*20, color= 'orange',  alpha=0.5)
plt.scatter(4, 19, s=dician_overcinquanta*20,color= 'orange', alpha=0.5)
plt.scatter(4, 20, s=venti_overcinquanta*20, color= 'orange' , alpha=0.5)





#=======RIFINITURE========
plt.hlines(y=11, xmin=1, xmax=5)

plt.title('Distribuzione demografica nelle prime 20 posizioni secondo ordinamento per data ')
plt.ylabel('Posizione in classifica', labelpad = 16)
plt.xlabel('Fascia di età' , labelpad = 16)
#setta ogni quante y ti fa vedere
plt.yticks(np.arange(0, 20, 5.0))
plt.xticks(np.arange(1, 6, 1.0))
plt.xticks([1,2,3,4],['under 30','30-40','40-55','over 55'],rotation=90)
plt.show()

# %%
dfr = dfr[dfr['typology'] == 'American']
#==========RISTORANTI AMERICANI RELEVANCE=======
primo_undertrenta = len(dfr[(dfr['age']<=30) & (dfr['number']==1)]) 
print(dfr[(dfr['age']<=30) & (dfr['number']==1)])
primo_trentaquaranta = len(dfr[(dfr['age']>30) & (dfr['age']<40) & (dfr['number']==1)])
primo_quarantacinquanta = len(dfr[(dfr['age']>=40) & (dfr['age']<55) & (dfr['number']==1)]) 
primo_overcinquanta = len(dfr[(dfr['age']>=55) & (dfr['number']==1)]) 

print(primo_undertrenta)
print(primo_trentaquaranta)
print(primo_quarantacinquanta)
print(primo_overcinquanta)

secondo_undertrenta = len(dfr[(dfr['age']<=30) & (dfr['number']==2)]) 
secondo_trentaquaranta = len(dfr[(dfr['age']>30) & (dfr['age']<40) & (dfr['number']==2)]) 
secondo_quarantacinquanta = len(dfr[(dfr['age']>=40) & (dfr['age']<55) & (dfr['number']==2)]) 
secondo_overcinquanta = len(dfr[(dfr['age']>=55) & (dfr['number']==2)]) 
print('=======SECONDO=====')
print(secondo_undertrenta)
print(secondo_trentaquaranta)
print(secondo_quarantacinquanta)
print(secondo_overcinquanta)

terzo_undertrenta = len(dfr[(dfr['age']<=30) & (dfr['number']==3)]) 
terzo_trentaquaranta = len(dfr[(dfr['age']>30) & (dfr['age']<40) & (dfr['number']==3)]) 
terzo_quarantacinquanta = len(dfr[(dfr['age']>=40) & (dfr['age']<55) & (dfr['number']==3)]) 
terzo_overcinquanta = len(dfr[(dfr['age']>=55) & (dfr['number']==3)]) 
print('=======TERZO=====')
print(terzo_undertrenta)
print(terzo_trentaquaranta)
print(terzo_quarantacinquanta)
print(terzo_overcinquanta)


quarto_undertrenta = len(dfr[(dfr['age']<=30) & (dfr['number']==4)]) 
quarto_trentaquaranta = len(dfr[(dfr['age']>30) & (dfr['age']<40) & (dfr['number']==4)]) 
quarto_quarantacinquanta = len(dfr[(dfr['age']>=40) & (dfr['age']<55) & (dfr['number']==4)]) 
quarto_overcinquanta = len(dfr[(dfr['age']>=55) & (dfr['number']==4)]) 

print('=======QUARTO=====')
print(quarto_undertrenta)
print(quarto_trentaquaranta)
print(quarto_quarantacinquanta)
print(quarto_overcinquanta)

quinto_undertrenta = len(dfr[(dfr['age']<=30) & (dfr['number']==5)]) 
quinto_trentaquaranta = len(dfr[(dfr['age']>30) & (dfr['age']<40) & (dfr['number']==5)]) 
quinto_quarantacinquanta = len(dfr[(dfr['age']>=40) & (dfr['age']<55) & (dfr['number']==5)]) 
quinto_overcinquanta = len(dfr[(dfr['age']>=55) & (dfr['number']==5)]) 

print('=======QUINTO=====')
print(quinto_undertrenta)
print(quinto_trentaquaranta)
print(quinto_quarantacinquanta)
print(quinto_overcinquanta)

sesto_undertrenta = len(dfr[(dfr['age']<=30) & (dfr['number']==6)]) 
sesto_trentaquaranta = len(dfr[(dfr['age']>30) & (dfr['age']<40) & (dfr['number']==6)]) 
sesto_quarantacinquanta = len(dfr[(dfr['age']>=40) & (dfr['age']<55) & (dfr['number']==6)]) 
sesto_overcinquanta = len(dfr[(dfr['age']>=55) & (dfr['number']==6)]) 

settimo_undertrenta = len(dfr[(dfr['age']<=30) & (dfr['number']==7)]) 
settimo_trentaquaranta = len(dfr[(dfr['age']>30) & (dfr['age']<40) & (dfr['number']==7)]) 
settimo_quarantacinquanta = len(dfr[(dfr['age']>=40) & (dfr['age']<55) & (dfr['number']==7)]) 
settimo_overcinquanta = len(dfr[(dfr['age']>=55) & (dfr['number']==7)]) 

ottavo_undertrenta = len(dfr[(dfr['age']<=30) & (dfr['number']==8)]) 
ottavo_trentaquaranta = len(dfr[(dfr['age']>30) & (dfr['age']<40) & (dfr['number']==8)]) 
ottavo_quarantacinquanta = len(dfr[(dfr['age']>=40) & (dfr['age']<55) & (dfr['number']==8)]) 
ottavo_overcinquanta = len(dfr[(dfr['age']>=55) & (dfr['number']==8)]) 

nono_undertrenta = len(dfr[(dfr['age']<=30) & (dfr['number']==9)]) 
nono_trentaquaranta = len(dfr[(dfr['age']>30) & (dfr['age']<40) & (dfr['number']==9)]) 
nono_quarantacinquanta = len(dfr[(dfr['age']>=40) & (dfr['age']<55) & (dfr['number']==9)]) 
nono_overcinquanta = len(dfr[(dfr['age']>=55) & (dfr['number']==9)]) 

decimo_undertrenta = len(dfr[(dfr['age']<=30) & (dfr['number']==10)]) 
decimo_trentaquaranta = len(dfr[(dfr['age']>30) & (dfr['age']<40) & (dfr['number']==10)]) 
decimo_quarantacinquanta = len(dfr[(dfr['age']>=40) & (dfr['age']<55) & (dfr['number']==10)]) 
decimo_overcinquanta = len(dfr[(dfr['age']>=55) & (dfr['number']==10)]) 

undicesimo_undertrenta = len(dfr[(dfr['age']<=30) & (dfr['number']==11)]) 
undicesimo_trentaquaranta = len(dfr[(dfr['age']>30) & (dfr['age']<40) & (dfr['number']==11)]) 
undicesimo_quarantacinquanta = len(dfr[(dfr['age']>=40) & (dfr['age']<55) & (dfr['number']==11)]) 
undicesimo_overcinquanta = len(dfr[(dfr['age']>=55) & (dfr['number']==11)]) 

dodicesimo_undertrenta = len(dfr[(dfr['age']<=30) & (dfr['number']==12)]) 
dodicesimo_trentaquaranta = len(dfr[(dfr['age']>30) & (dfr['age']<40) & (dfr['number']==12)]) 
dodicesimo_quarantacinquanta = len(dfr[(dfr['age']>=40) & (dfr['age']<55) & (dfr['number']==12)]) 
dodicesimo_overcinquanta = len(dfr[(dfr['age']>=55) & (dfr['number']==12)]) 

tredi_undertrenta = len(dfr[(dfr['age']<=30) & (dfr['number']==13)]) 
tredi_trentaquaranta = len(dfr[(dfr['age']>30) & (dfr['age']<40) & (dfr['number']==13)]) 
tredi_quarantacinquanta = len(dfr[(dfr['age']>=40) & (dfr['age']<55) & (dfr['number']==13)]) 
tredi_overcinquanta = len(dfr[(dfr['age']>=55) & (dfr['number']==13)]) 

quattordi_undertrenta = len(dfr[(dfr['age']<=30) & (dfr['number']==14)]) 
quattordi_trentaquaranta = len(dfr[(dfr['age']>30) & (dfr['age']<40) & (dfr['number']==14)]) 
quattordi_quarantacinquanta = len(dfr[(dfr['age']>=40) & (dfr['age']<55) & (dfr['number']==14)]) 
quattordi_overcinquanta = len(dfr[(dfr['age']>=55) & (dfr['number']==14)]) 

quindi_undertrenta = len(dfr[(dfr['age']<=30) & (dfr['number']==15)]) 
quindi_trentaquaranta = len(dfr[(dfr['age']>30) & (dfr['age']<40) & (dfr['number']==15)]) 
quindi_quarantacinquanta = len(dfr[(dfr['age']>=40) & (dfr['age']<55) & (dfr['number']==15)]) 
quindi_overcinquanta = len(dfr[(dfr['age']>=55) & (dfr['number']==15)]) 

sedi_undertrenta = len(dfr[(dfr['age']<=30) & (dfr['number']==16)]) 
sedi_trentaquaranta = len(dfr[(dfr['age']>30) & (dfr['age']<40) & (dfr['number']==16)]) 
sedi_quarantacinquanta = len(dfr[(dfr['age']>=40) & (dfr['age']<55) & (dfr['number']==16)]) 
sedi_overcinquanta = len(dfr[(dfr['age']>=55) & (dfr['number']==16)]) 

dicia_undertrenta = len(dfr[(dfr['age']<=30) & (dfr['number']==17)]) 
dicia_trentaquaranta = len(dfr[(dfr['age']>30) & (dfr['age']<40) & (dfr['number']==17)]) 
dicia_quarantacinquanta = len(dfr[(dfr['age']>=40) & (dfr['age']<55) & (dfr['number']==17)]) 
dicia_overcinquanta = len(dfr[(dfr['age']>=55) & (dfr['number']==17)]) 

dicio_undertrenta = len(dfr[(dfr['age']<=30) & (dfr['number']==18)]) 
dicio_trentaquaranta = len(dfr[(dfr['age']>30) & (dfr['age']<40) & (dfr['number']==18)]) 
dicio_quarantacinquanta = len(dfr[(dfr['age']>=40) & (dfr['age']<55) & (dfr['number']==18)]) 
dicio_overcinquanta = len(dfr[(dfr['age']>=55) & (dfr['number']==18)]) 

dician_undertrenta = len(dfr[(dfr['age']<=30) & (dfr['number']==19)]) 
dician_trentaquaranta = len(dfr[(dfr['age']>30) & (dfr['age']<40) & (dfr['number']==19)]) 
dician_quarantacinquanta = len(dfr[(dfr['age']>=40) & (dfr['age']<55) & (dfr['number']==19)]) 
dician_overcinquanta = len(dfr[(dfr['age']>=55) & (dfr['number']==19)]) 

venti_undertrenta = len(dfr[(dfr['age']<=30) & (dfr['number']==20)]) 
venti_trentaquaranta = len(dfr[(dfr['age']>30) & (dfr['age']<40) & (dfr['number']==20)]) 
venti_quarantacinquanta = len(dfr[(dfr['age']>=40) & (dfr['age']<55) & (dfr['number']==20)]) 
venti_overcinquanta = len(dfr[(dfr['age']>=55) & (dfr['number']==20)])

# %%
#================COSTRUISCO GRAFICO RISTORANTI AMERICANI RELEVANCE=====================
plt.subplot()
#fig, ax = plt.subplots()

#=======<30=======
plt.scatter(1, 1, s=primo_undertrenta*50, color= 'blue' , alpha=0.5, label='undertrenta')
plt.scatter(1, 2, s = secondo_undertrenta*50, color= 'blue',  alpha=0.5)
plt.scatter(1, 3, s=terzo_undertrenta*50,color= 'blue', alpha=0.5)
plt.scatter(1, 4, s=quarto_undertrenta*50, color= 'blue' , alpha=0.5)
plt.scatter(1, 5, s = quinto_undertrenta*50, color= 'blue',  alpha=0.5)
plt.scatter(1, 6, s=sesto_undertrenta*50,color= 'blue', alpha=0.5)
plt.scatter(1, 7, s=settimo_undertrenta*50, color= 'blue' , alpha=0.5)
plt.scatter(1, 8, s = ottavo_undertrenta*50, color= 'blue',  alpha=0.5)
plt.scatter(1, 9, s=nono_undertrenta*50,color= 'blue', alpha=0.5)
plt.scatter(1, 10, s=decimo_undertrenta*50, color= 'blue' , alpha=0.5)
plt.scatter(1, 11, s=undicesimo_undertrenta*50, color= 'blue' , alpha=0.5)
plt.scatter(1, 12, s = dodicesimo_undertrenta*50, color= 'blue',  alpha=0.5)
plt.scatter(1, 13, s=tredi_undertrenta*50,color= 'blue', alpha=0.5)
plt.scatter(1, 14, s=quattordi_undertrenta*50, color= 'blue' , alpha=0.5)
plt.scatter(1, 15, s = quindi_undertrenta*50, color= 'blue',  alpha=0.5)
plt.scatter(1, 16, s=sedi_undertrenta*50,color= 'blue', alpha=0.5)
plt.scatter(1, 17, s=dicia_undertrenta*50, color= 'blue' , alpha=0.5)
plt.scatter(1, 18, s = dicio_undertrenta*50, color= 'blue',  alpha=0.5)
plt.scatter(1, 19, s=dician_undertrenta*50,color= 'blue', alpha=0.5)
plt.scatter(1, 20, s=venti_undertrenta*50, color= 'blue' , alpha=0.5)

#====30-40=====
plt.scatter(2, 1, s=primo_trentaquaranta*50, color= 'green' , alpha=0.5, label='trentaquaranta')
plt.scatter(2, 2, s = secondo_trentaquaranta*50, color= 'green',  alpha=0.5)
plt.scatter(2, 3, s=terzo_trentaquaranta*50,color= 'green', alpha=0.5)
plt.scatter(2, 4, s=quarto_trentaquaranta*50, color= 'green' , alpha=0.5)
plt.scatter(2, 5, s = quinto_trentaquaranta*50, color= 'green',  alpha=0.5)
plt.scatter(2, 6, s=sesto_trentaquaranta*50,color= 'green', alpha=0.5)
plt.scatter(2, 7, s=settimo_trentaquaranta*50, color= 'green' , alpha=0.5)
plt.scatter(2, 8, s = ottavo_trentaquaranta*50, color= 'green',  alpha=0.5)
plt.scatter(2, 9, s=nono_trentaquaranta*50,color= 'green', alpha=0.5)
plt.scatter(2, 10, s=decimo_trentaquaranta*50, color= 'green' , alpha=0.5)
plt.scatter(2, 11, s=undicesimo_trentaquaranta*50, color= 'green' , alpha=0.5)
plt.scatter(2, 12, s = dodicesimo_trentaquaranta*50, color= 'green',  alpha=0.5)
plt.scatter(2, 13, s=tredi_trentaquaranta*50,color= 'green', alpha=0.5)
plt.scatter(2, 14, s=quattordi_trentaquaranta*50, color= 'green' , alpha=0.5)
plt.scatter(2, 15, s = quindi_trentaquaranta*50, color= 'green',  alpha=0.5)
plt.scatter(2, 16, s=sedi_trentaquaranta*50,color= 'green', alpha=0.5)
plt.scatter(2, 17, s=dicia_trentaquaranta*50, color= 'green' , alpha=0.5)
plt.scatter(2, 18, s = dicio_trentaquaranta*50, color= 'green',  alpha=0.5)
plt.scatter(2, 19, s=dician_trentaquaranta*50,color= 'green', alpha=0.5)
plt.scatter(2, 20, s=venti_trentaquaranta*50, color= 'green' , alpha=0.5)

#======40-55=========
plt.scatter(3, 1, s=primo_quarantacinquanta*50, color= 'red' , alpha=0.5)
plt.scatter(3, 2, s = secondo_quarantacinquanta*50, color= 'red',  alpha=0.5)
plt.scatter(3, 3, s=terzo_quarantacinquanta*50,color= 'red', alpha=0.5)
plt.scatter(3, 4, s=quarto_quarantacinquanta*50, color= 'red' , alpha=0.5)
plt.scatter(3, 5, s = quinto_quarantacinquanta*50, color= 'red',  alpha=0.5)
plt.scatter(3, 6, s=sesto_quarantacinquanta*50,color= 'red', alpha=0.5)
plt.scatter(3, 7, s=settimo_quarantacinquanta*50, color= 'red' , alpha=0.5)
plt.scatter(3, 8, s = ottavo_quarantacinquanta*50, color= 'red',  alpha=0.5)
plt.scatter(3, 9, s=nono_quarantacinquanta*50,color= 'red', alpha=0.5)
plt.scatter(3, 10, s=decimo_quarantacinquanta*50, color= 'red' , alpha=0.5)
plt.scatter(3, 11, s=undicesimo_quarantacinquanta*50, color= 'red' , alpha=0.5)
plt.scatter(3, 12, s = dodicesimo_quarantacinquanta*50, color= 'red',  alpha=0.5)
plt.scatter(3, 13, s=tredi_quarantacinquanta*50,color= 'red', alpha=0.5)
plt.scatter(3, 14, s=quattordi_quarantacinquanta*50, color= 'red' , alpha=0.5)
plt.scatter(3, 15, s = quindi_quarantacinquanta*50, color= 'red',  alpha=0.5)
plt.scatter(3, 16, s=sedi_quarantacinquanta*50,color= 'red', alpha=0.5)
plt.scatter(3, 17, s=dicia_quarantacinquanta*50, color= 'red' , alpha=0.5)
plt.scatter(3, 18, s = dicio_quarantacinquanta*50, color= 'red',  alpha=0.5)
plt.scatter(3, 19, s=dician_quarantacinquanta*50,color= 'red', alpha=0.5)
plt.scatter(3, 20, s=venti_quarantacinquanta*50, color= 'red' , alpha=0.5)


#========>55=======
plt.scatter(4, 1, s=primo_overcinquanta*50, color= 'orange' , alpha=0.5)
plt.scatter(4, 2, s = secondo_overcinquanta*50, color= 'orange',  alpha=0.5)
plt.scatter(4, 3, s=terzo_overcinquanta*50,color= 'orange', alpha=0.5)
plt.scatter(4, 4, s=quarto_overcinquanta*50, color= 'orange' , alpha=0.5)
plt.scatter(4, 5, s = quinto_overcinquanta*50, color= 'orange',  alpha=0.5)
plt.scatter(4, 6, s=sesto_overcinquanta*50,color= 'orange', alpha=0.5)
plt.scatter(4, 7, s=settimo_overcinquanta*50, color= 'orange' , alpha=0.5)
plt.scatter(4, 8, s = ottavo_overcinquanta*50, color= 'orange',  alpha=0.5)
plt.scatter(4, 9, s=nono_overcinquanta*50,color= 'orange', alpha=0.5)
plt.scatter(4, 10, s=decimo_overcinquanta*50, color= 'orange' , alpha=0.5)
plt.scatter(4, 11, s=undicesimo_overcinquanta*50, color= 'orange' , alpha=0.5)
plt.scatter(4, 12, s = dodicesimo_overcinquanta*50, color= 'orange',  alpha=0.5)
plt.scatter(4, 13, s=tredi_overcinquanta*50,color= 'orange', alpha=0.5)
plt.scatter(4, 14, s=quattordi_overcinquanta*50, color= 'orange' , alpha=0.5)
plt.scatter(4, 15, s = quindi_overcinquanta*50, color= 'orange',  alpha=0.5)
plt.scatter(4, 16, s=sedi_overcinquanta*50,color= 'orange', alpha=0.5)
plt.scatter(4, 17, s=dicia_overcinquanta*50, color= 'orange' , alpha=0.5)
plt.scatter(4, 18, s = dicio_overcinquanta*50, color= 'orange',  alpha=0.5)
plt.scatter(4, 19, s=dician_overcinquanta*50,color= 'orange', alpha=0.5)
plt.scatter(4, 20, s=venti_overcinquanta*50, color= 'orange' , alpha=0.5)




#=======RIFINITURE========
plt.hlines(y=11, xmin=1, xmax=5)

plt.title('Distribuzione demografica nelle prime 20 posizioni secondo ordinamento di Yelp ')
plt.ylabel('Posizione in classifica', labelpad = 16)
plt.xlabel('Fascia di età' , labelpad = 16)
#setta ogni quante y ti fa vedere
plt.yticks(np.arange(0, 20, 5.0))
plt.xticks(np.arange(1, 6, 1.0))
plt.xticks([1,2,3,4],['under 30','30-40','40-55','over 55'],rotation=90)
plt.show()

# %%
#======RISTORANTI AMERICANI DATA=====
dfd = dfd[dfd['typology'] == 'American']
primo_undertrenta = len(dfd[(dfd['age']<=30) & (dfd['number']==1)]) 
print(dfd[(dfd['age']<=30) & (dfd['number']==1)])
primo_trentaquaranta = len(dfd[(dfd['age']>30) & (dfd['age']<40) & (dfd['number']==1)])
primo_quarantacinquanta = len(dfd[(dfd['age']>=40) & (dfd['age']<55) & (dfd['number']==1)]) 
primo_overcinquanta = len(dfd[(dfd['age']>=55) & (dfd['number']==1)]) 

print(primo_undertrenta)
print(primo_trentaquaranta)
print(primo_quarantacinquanta)
print(primo_overcinquanta)

secondo_undertrenta = len(dfd[(dfd['age']<=30) & (dfd['number']==2)]) 
secondo_trentaquaranta = len(dfd[(dfd['age']>30) & (dfd['age']<40) & (dfd['number']==2)]) 
secondo_quarantacinquanta = len(dfd[(dfd['age']>=40) & (dfd['age']<55) & (dfd['number']==2)]) 
secondo_overcinquanta = len(dfd[(dfd['age']>=55) & (dfd['number']==2)]) 
print('=======SECONDO=====')
print(secondo_undertrenta)
print(secondo_trentaquaranta)
print(secondo_quarantacinquanta)
print(secondo_overcinquanta)

terzo_undertrenta = len(dfd[(dfd['age']<=30) & (dfd['number']==3)]) 
terzo_trentaquaranta = len(dfd[(dfd['age']>30) & (dfd['age']<40) & (dfd['number']==3)]) 
terzo_quarantacinquanta = len(dfd[(dfd['age']>=40) & (dfd['age']<55) & (dfd['number']==3)]) 
terzo_overcinquanta = len(dfd[(dfd['age']>=55) & (dfd['number']==3)]) 
print('=======TERZO=====')
print(terzo_undertrenta)
print(terzo_trentaquaranta)
print(terzo_quarantacinquanta)
print(terzo_overcinquanta)

quarto_undertrenta = len(dfd[(dfd['age']<=30) & (dfd['number']==4)]) 
quarto_trentaquaranta = len(dfd[(dfd['age']>30) & (dfd['age']<40) & (dfd['number']==4)]) 
quarto_quarantacinquanta = len(dfd[(dfd['age']>=40) & (dfd['age']<55) & (dfd['number']==4)]) 
quarto_overcinquanta = len(dfd[(dfd['age']>=55) & (dfd['number']==4)]) 

print('=======QUARTO=====')
print(quarto_undertrenta)
print(quarto_trentaquaranta)
print(quarto_quarantacinquanta)
print(quarto_overcinquanta)

quinto_undertrenta = len(dfd[(dfd['age']<=30) & (dfd['number']==5)]) 
quinto_trentaquaranta = len(dfd[(dfd['age']>30) & (dfd['age']<40) & (dfd['number']==5)]) 
quinto_quarantacinquanta = len(dfd[(dfd['age']>=40) & (dfd['age']<55) & (dfd['number']==5)]) 
quinto_overcinquanta = len(dfd[(dfd['age']>=55) & (dfd['number']==5)]) 

print('=======QUINTO=====')
print(quinto_undertrenta)
print(quinto_trentaquaranta)
print(quinto_quarantacinquanta)
print(quinto_overcinquanta)

sesto_undertrenta = len(dfd[(dfd['age']<=30) & (dfd['number']==6)]) 
sesto_trentaquaranta = len(dfd[(dfd['age']>30) & (dfd['age']<40) & (dfd['number']==6)]) 
sesto_quarantacinquanta = len(dfd[(dfd['age']>=40) & (dfd['age']<55) & (dfd['number']==6)]) 
sesto_overcinquanta = len(dfd[(dfd['age']>=55) & (dfd['number']==6)]) 

settimo_undertrenta = len(dfd[(dfd['age']<=30) & (dfd['number']==7)]) 
settimo_trentaquaranta = len(dfd[(dfd['age']>30) & (dfd['age']<40) & (dfd['number']==7)]) 
settimo_quarantacinquanta = len(dfd[(dfd['age']>=40) & (dfd['age']<55) & (dfd['number']==7)]) 
settimo_overcinquanta = len(dfd[(dfd['age']>=55) & (dfd['number']==7)]) 

ottavo_undertrenta = len(dfd[(dfd['age']<=30) & (dfd['number']==8)]) 
ottavo_trentaquaranta = len(dfd[(dfd['age']>30) & (dfd['age']<40) & (dfd['number']==8)]) 
ottavo_quarantacinquanta = len(dfd[(dfd['age']>=40) & (dfd['age']<55) & (dfd['number']==8)]) 
ottavo_overcinquanta = len(dfd[(dfd['age']>=55) & (dfd['number']==8)]) 

nono_undertrenta = len(dfd[(dfd['age']<=30) & (dfd['number']==9)]) 
nono_trentaquaranta = len(dfd[(dfd['age']>30) & (dfd['age']<40) & (dfd['number']==9)]) 
nono_quarantacinquanta = len(dfd[(dfd['age']>=40) & (dfd['age']<55) & (dfd['number']==9)]) 
nono_overcinquanta = len(dfd[(dfd['age']>=55) & (dfd['number']==9)]) 

decimo_undertrenta = len(dfd[(dfd['age']<=30) & (dfd['number']==10)]) 
decimo_trentaquaranta = len(dfd[(dfd['age']>30) & (dfd['age']<40) & (dfd['number']==10)]) 
decimo_quarantacinquanta = len(dfd[(dfd['age']>=40) & (dfd['age']<55) & (dfd['number']==10)]) 
decimo_overcinquanta = len(dfd[(dfd['age']>=55) & (dfd['number']==10)]) 

undicesimo_undertrenta = len(dfd[(dfd['age']<=30) & (dfd['number']==11)]) 
undicesimo_trentaquaranta = len(dfd[(dfd['age']>30) & (dfd['age']<40) & (dfd['number']==11)]) 
undicesimo_quarantacinquanta = len(dfd[(dfd['age']>=40) & (dfd['age']<55) & (dfd['number']==11)]) 
undicesimo_overcinquanta = len(dfd[(dfd['age']>=55) & (dfd['number']==11)]) 

dodicesimo_undertrenta = len(dfd[(dfd['age']<=30) & (dfd['number']==12)]) 
dodicesimo_trentaquaranta = len(dfd[(dfd['age']>30) & (dfd['age']<40) & (dfd['number']==12)]) 
dodicesimo_quarantacinquanta = len(dfd[(dfd['age']>=40) & (dfd['age']<55) & (dfd['number']==12)]) 
dodicesimo_overcinquanta = len(dfd[(dfd['age']>=55) & (dfd['number']==12)]) 

tredi_undertrenta = len(dfd[(dfd['age']<=30) & (dfd['number']==13)]) 
tredi_trentaquaranta = len(dfd[(dfd['age']>30) & (dfd['age']<40) & (dfd['number']==13)]) 
tredi_quarantacinquanta = len(dfd[(dfd['age']>=40) & (dfd['age']<55) & (dfd['number']==13)]) 
tredi_overcinquanta = len(dfd[(dfd['age']>=55) & (dfd['number']==13)]) 

quattordi_undertrenta = len(dfd[(dfd['age']<=30) & (dfd['number']==14)]) 
quattordi_trentaquaranta = len(dfd[(dfd['age']>30) & (dfd['age']<40) & (dfd['number']==14)]) 
quattordi_quarantacinquanta = len(dfd[(dfd['age']>=40) & (dfd['age']<55) & (dfd['number']==14)]) 
quattordi_overcinquanta = len(dfd[(dfd['age']>=55) & (dfd['number']==14)]) 

quindi_undertrenta = len(dfd[(dfd['age']<=30) & (dfd['number']==15)]) 
quindi_trentaquaranta = len(dfd[(dfd['age']>30) & (dfd['age']<40) & (dfd['number']==15)]) 
quindi_quarantacinquanta = len(dfd[(dfd['age']>=40) & (dfd['age']<55) & (dfd['number']==15)]) 
quindi_overcinquanta = len(dfd[(dfd['age']>=55) & (dfd['number']==15)]) 

sedi_undertrenta = len(dfd[(dfd['age']<=30) & (dfd['number']==16)]) 
sedi_trentaquaranta = len(dfd[(dfd['age']>30) & (dfd['age']<40) & (dfd['number']==16)]) 
sedi_quarantacinquanta = len(dfd[(dfd['age']>=40) & (dfd['age']<55) & (dfd['number']==16)]) 
sedi_overcinquanta = len(dfd[(dfd['age']>=55) & (dfd['number']==16)]) 

dicia_undertrenta = len(dfd[(dfd['age']<=30) & (dfd['number']==17)]) 
dicia_trentaquaranta = len(dfd[(dfd['age']>30) & (dfd['age']<40) & (dfd['number']==17)]) 
dicia_quarantacinquanta = len(dfd[(dfd['age']>=40) & (dfd['age']<55) & (dfd['number']==17)]) 
dicia_overcinquanta = len(dfd[(dfd['age']>=55) & (dfd['number']==17)]) 

dicio_undertrenta = len(dfd[(dfd['age']<=30) & (dfd['number']==18)]) 
dicio_trentaquaranta = len(dfd[(dfd['age']>30) & (dfd['age']<40) & (dfd['number']==18)]) 
dicio_quarantacinquanta = len(dfd[(dfd['age']>=40) & (dfd['age']<55) & (dfd['number']==18)]) 
dicio_overcinquanta = len(dfd[(dfd['age']>=55) & (dfd['number']==18)]) 

dician_undertrenta = len(dfd[(dfd['age']<=30) & (dfd['number']==19)]) 
dician_trentaquaranta = len(dfd[(dfd['age']>30) & (dfd['age']<40) & (dfd['number']==19)]) 
dician_quarantacinquanta = len(dfd[(dfd['age']>=40) & (dfd['age']<55) & (dfd['number']==19)]) 
dician_overcinquanta = len(dfd[(dfd['age']>=55) & (dfd['number']==19)]) 

venti_undertrenta = len(dfd[(dfd['age']<=30) & (dfd['number']==20)]) 
venti_trentaquaranta = len(dfd[(dfd['age']>30) & (dfd['age']<40) & (dfd['number']==20)]) 
venti_quarantacinquanta = len(dfd[(dfd['age']>=40) & (dfd['age']<55) & (dfd['number']==20)]) 
venti_overcinquanta = len(dfd[(dfd['age']>=55) & (dfd['number']==20)])

# %%
#================COSTRUISCO GRAFICO DATA=====================
plt.subplot()
#fig, ax = plt.subplots()

#=======<30=======
plt.scatter(1, 1, s=primo_undertrenta*50, color= 'blue' , alpha=0.5, label='undertrenta')
plt.scatter(1, 2, s = secondo_undertrenta*50, color= 'blue',  alpha=0.5)
plt.scatter(1, 3, s=terzo_undertrenta*50,color= 'blue', alpha=0.5)
plt.scatter(1, 4, s=quarto_undertrenta*50, color= 'blue' , alpha=0.5)
plt.scatter(1, 5, s = quinto_undertrenta*50, color= 'blue',  alpha=0.5)
plt.scatter(1, 6, s=sesto_undertrenta*50,color= 'blue', alpha=0.5)
plt.scatter(1, 7, s=settimo_undertrenta*50, color= 'blue' , alpha=0.5)
plt.scatter(1, 8, s = ottavo_undertrenta*50, color= 'blue',  alpha=0.5)
plt.scatter(1, 9, s=nono_undertrenta*50,color= 'blue', alpha=0.5)
plt.scatter(1, 10, s=decimo_undertrenta*50, color= 'blue' , alpha=0.5)
plt.scatter(1, 11, s=undicesimo_undertrenta*50, color= 'blue' , alpha=0.5)
plt.scatter(1, 12, s = dodicesimo_undertrenta*50, color= 'blue',  alpha=0.5)
plt.scatter(1, 13, s=tredi_undertrenta*50,color= 'blue', alpha=0.5)
plt.scatter(1, 14, s=quattordi_undertrenta*50, color= 'blue' , alpha=0.5)
plt.scatter(1, 15, s = quindi_undertrenta*50, color= 'blue',  alpha=0.5)
plt.scatter(1, 16, s=sedi_undertrenta*50,color= 'blue', alpha=0.5)
plt.scatter(1, 17, s=dicia_undertrenta*50, color= 'blue' , alpha=0.5)
plt.scatter(1, 18, s = dicio_undertrenta*50, color= 'blue',  alpha=0.5)
plt.scatter(1, 19, s=dician_undertrenta*50,color= 'blue', alpha=0.5)
plt.scatter(1, 20, s=venti_undertrenta*50, color= 'blue' , alpha=0.5)

#====30-40=====
plt.scatter(2, 1, s=primo_trentaquaranta*50, color= 'green' , alpha=0.5, label='trentaquaranta')
plt.scatter(2, 2, s = secondo_trentaquaranta*50, color= 'green',  alpha=0.5)
plt.scatter(2, 3, s=terzo_trentaquaranta*50,color= 'green', alpha=0.5)
plt.scatter(2, 4, s=quarto_trentaquaranta*50, color= 'green' , alpha=0.5)
plt.scatter(2, 5, s = quinto_trentaquaranta*50, color= 'green',  alpha=0.5)
plt.scatter(2, 6, s=sesto_trentaquaranta*50,color= 'green', alpha=0.5)
plt.scatter(2, 7, s=settimo_trentaquaranta*50, color= 'green' , alpha=0.5)
plt.scatter(2, 8, s = ottavo_trentaquaranta*50, color= 'green',  alpha=0.5)
plt.scatter(2, 9, s=nono_trentaquaranta*50,color= 'green', alpha=0.5)
plt.scatter(2, 10, s=decimo_trentaquaranta*50, color= 'green' , alpha=0.5)
plt.scatter(2, 11, s=undicesimo_trentaquaranta*50, color= 'green' , alpha=0.5)
plt.scatter(2, 12, s = dodicesimo_trentaquaranta*50, color= 'green',  alpha=0.5)
plt.scatter(2, 13, s=tredi_trentaquaranta*50,color= 'green', alpha=0.5)
plt.scatter(2, 14, s=quattordi_trentaquaranta*50, color= 'green' , alpha=0.5)
plt.scatter(2, 15, s = quindi_trentaquaranta*50, color= 'green',  alpha=0.5)
plt.scatter(2, 16, s=sedi_trentaquaranta*50,color= 'green', alpha=0.5)
plt.scatter(2, 17, s=dicia_trentaquaranta*50, color= 'green' , alpha=0.5)
plt.scatter(2, 18, s = dicio_trentaquaranta*50, color= 'green',  alpha=0.5)
plt.scatter(2, 19, s=dician_trentaquaranta*50,color= 'green', alpha=0.5)
plt.scatter(2, 20, s=venti_trentaquaranta*50, color= 'green' , alpha=0.5)

#======40-55=========
plt.scatter(3, 1, s=primo_quarantacinquanta*50, color= 'red' , alpha=0.5)
plt.scatter(3, 2, s = secondo_quarantacinquanta*50, color= 'red',  alpha=0.5)
plt.scatter(3, 3, s=terzo_quarantacinquanta*50,color= 'red', alpha=0.5)
plt.scatter(3, 4, s=quarto_quarantacinquanta*50, color= 'red' , alpha=0.5)
plt.scatter(3, 5, s = quinto_quarantacinquanta*50, color= 'red',  alpha=0.5)
plt.scatter(3, 6, s=sesto_quarantacinquanta*50,color= 'red', alpha=0.5)
plt.scatter(3, 7, s=settimo_quarantacinquanta*50, color= 'red' , alpha=0.5)
plt.scatter(3, 8, s = ottavo_quarantacinquanta*50, color= 'red',  alpha=0.5)
plt.scatter(3, 9, s=nono_quarantacinquanta*50,color= 'red', alpha=0.5)
plt.scatter(3, 10, s=decimo_quarantacinquanta*50, color= 'red' , alpha=0.5)
plt.scatter(3, 11, s=undicesimo_quarantacinquanta*50, color= 'red' , alpha=0.5)
plt.scatter(3, 12, s = dodicesimo_quarantacinquanta*50, color= 'red',  alpha=0.5)
plt.scatter(3, 13, s=tredi_quarantacinquanta*50,color= 'red', alpha=0.5)
plt.scatter(3, 14, s=quattordi_quarantacinquanta*50, color= 'red' , alpha=0.5)
plt.scatter(3, 15, s = quindi_quarantacinquanta*50, color= 'red',  alpha=0.5)
plt.scatter(3, 16, s=sedi_quarantacinquanta*50,color= 'red', alpha=0.5)
plt.scatter(3, 17, s=dicia_quarantacinquanta*50, color= 'red' , alpha=0.5)
plt.scatter(3, 18, s = dicio_quarantacinquanta*50, color= 'red',  alpha=0.5)
plt.scatter(3, 19, s=dician_quarantacinquanta*50,color= 'red', alpha=0.5)
plt.scatter(3, 20, s=venti_quarantacinquanta*50, color= 'red' , alpha=0.5)


#========>55=======
plt.scatter(4, 1, s=primo_overcinquanta*50, color= 'orange' , alpha=0.5)
plt.scatter(4, 2, s = secondo_overcinquanta*50, color= 'orange',  alpha=0.5)
plt.scatter(4, 3, s=terzo_overcinquanta*50,color= 'orange', alpha=0.5)
plt.scatter(4, 4, s=quarto_overcinquanta*50, color= 'orange' , alpha=0.5)
plt.scatter(4, 5, s = quinto_overcinquanta*50, color= 'orange',  alpha=0.5)
plt.scatter(4, 6, s=sesto_overcinquanta*50,color= 'orange', alpha=0.5)
plt.scatter(4, 7, s=settimo_overcinquanta*50, color= 'orange' , alpha=0.5)
plt.scatter(4, 8, s = ottavo_overcinquanta*50, color= 'orange',  alpha=0.5)
plt.scatter(4, 9, s=nono_overcinquanta*50,color= 'orange', alpha=0.5)
plt.scatter(4, 10, s=decimo_overcinquanta*50, color= 'orange' , alpha=0.5)
plt.scatter(4, 11, s=undicesimo_overcinquanta*50, color= 'orange' , alpha=0.5)
plt.scatter(4, 12, s = dodicesimo_overcinquanta*50, color= 'orange',  alpha=0.5)
plt.scatter(4, 13, s=tredi_overcinquanta*50,color= 'orange', alpha=0.5)
plt.scatter(4, 14, s=quattordi_overcinquanta*50, color= 'orange' , alpha=0.5)
plt.scatter(4, 15, s = quindi_overcinquanta*50, color= 'orange',  alpha=0.5)
plt.scatter(4, 16, s=sedi_overcinquanta*50,color= 'orange', alpha=0.5)
plt.scatter(4, 17, s=dicia_overcinquanta*50, color= 'orange' , alpha=0.5)
plt.scatter(4, 18, s = dicio_overcinquanta*50, color= 'orange',  alpha=0.5)
plt.scatter(4, 19, s=dician_overcinquanta*50,color= 'orange', alpha=0.5)
plt.scatter(4, 20, s=venti_overcinquanta*50, color= 'orange' , alpha=0.5)




#=======RIFINITURE========
plt.hlines(y=11, xmin=1, xmax=5)

plt.title('Distribuzione demografica di 3 ristoranti americani nelle prime 20 posizioni secondo ordinamento per data ')
plt.ylabel('Posizione in classifica', labelpad = 16)
plt.xlabel('Fascia di età' , labelpad = 16)
#setta ogni quante y ti fa vedere
plt.yticks(np.arange(0, 20, 5.0))
plt.xticks(np.arange(1, 6, 1.0))
plt.xticks([1,2,3,4],['under 30','30-40','40-55','over 55'],rotation=90)
plt.show()

# %%
#=========GIAPPONESI========

# %%
#=========MESSICANI==========
